# %% [markdown]
# **Practical 05 : simple rule based expert system**

# %% [markdown]
# 02: BUILD THE EXPERT SYSTEM

# %%
def laptop_expert(turns_on, internet_works, is_slow):
  if turns_on == "no":
    return "check power cable of the laptop"
  elif internet_works == "no":
    return "check Wi-Fi and restart the router"
  elif is_slow == "yes":
    return "close unused programs and restart the laptop"
  else :
    return "no common problem in the system"

# %% [markdown]
# 03: UNDERSTAND THE CODE

# %%
turns_on =input("Does the laptop turn on? yes/no: ").lower()
internet_works =input("Does internet work? yes/no: ").lower()
is_slow =input("Is the laptop slow? yes/no: ").lower()

advice = laptop_expert(turns_on, internet_works, is_slow)
print("\nExpert System Advise")
print(advice)
# Out:
# Does the laptop turn on? yes/no: YES
# Does internet work? yes/no: NO
# Is the laptop slow? yes/no: YES
#
# Expert System Advise
# check Wi-Fi and restart the router
